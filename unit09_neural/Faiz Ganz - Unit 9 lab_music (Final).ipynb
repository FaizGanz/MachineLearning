# %% [markdown]
# # Lab:  Neural Networks for Music Classification
#
# In addition to the concepts in the [MNIST neural network demo](./demo2_mnist_neural.ipynb), in this lab, you will learn to:
# * Load a file from a URL
# * Extract simple features from audio samples for machine learning tasks such as speech recognition and classification
# * Build a simple neural network for music classification using these features
# * Use a callback to store the loss and accuracy history in the training process
# * Optimize the learning rate of the neural network
#
# To illustrate the basic concepts, we will look at a relatively simple music classification problem.  Given a sample of music, we want to determine which instrument (e.g. trumpet, violin, piano) is playing.  This dataset was generously supplied by [Prof. Juan Bello](http://steinhardt.nyu.edu/faculty/Juan_Pablo_Bello) at NYU Stenihardt  and his former PhD student Eric Humphrey (now at Spotify).  They have a complete website dedicated to deep learning methods in music informatics:
#
# http://marl.smusic.nyu.edu/wordpress/projects/feature-learning-deep-architectures/deep-learning-python-tutorial/
#
# You can also check out Juan's <a href="http://www.nyu.edu/classes/bello/ACA.html">course</a>.

# %% [markdown]
# ## Loading Tensorflow
#
# Before starting this lab, you will need to install [Tensorflow](https://www.tensorflow.org/install/).  If you are using [Google colaboratory](https://colab.research.google.com), Tensorflow is already installed.  Run the following command to ensure Tensorflow is installed.

# %%
import tensorflow as tf

# %% [markdown]
# Then, load the other packages.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Audio Feature Extraction with Librosa
#
# The key to audio classification is to extract the correct features. In addition to `keras`, we will need the `librosa` package.  The `librosa` package in python has a rich set of methods extracting the features of audio samples commonly used in machine learning tasks such as speech recognition and sound classification.
#
# Installation instructions and complete documentation for the package are given on the [librosa main page](https://librosa.github.io/librosa/).  On most systems, you should be able to simply use:
#
#     pip install librosa
#
# For Unix, you may need to load some additional packages:
#
#     sudo apt-get install build-essential
#     sudo apt-get install libxext-dev python-qt4 qt4-dev-tools
#     pip install librosa
#
# After you have installed the package, try to import it.

# %%
import librosa
import librosa.display
import librosa.feature

# %% [markdown]
# In this lab, we will use a set of music samples from the website:
#
# http://theremin.music.uiowa.edu
#
# This website has a great set of samples for audio processing.  Look on the web for how to use the `requests.get` and `file.write` commands to load the file at the URL provided into your working directory.
#
# You can play the audio sample by copying the file to your local machine and playing it on any media player.  If you listen to it you will hear a soprano saxaphone (with vibrato) playing four notes (C, C#, D, Eb).

# %%
import requests
fn = "SopSax.Vib.pp.C6Eb6.aiff"
url = "http://theremin.music.uiowa.edu/sound files/MIS/Woodwinds/sopranosaxophone/"+fn

# TODO 1:  Load the file from url and save it in a file under the name fn
r = requests.get(url)  
with open(fn, 'wb') as f:
    f.write(r.content)

# %% [markdown]
# Next, use `librosa` command `librosa.load` to read the audio file with filename `fn` and get the samples `y` and sample rate `sr`.

# %%
# TODO 2
y, sr = librosa.load(fn)

# %% [markdown]
# Extracting features from audio files is an entire subject on its own right.  A commonly used set of features are called the Mel Frequency Cepstral Coefficients (MFCCs).  These are derived from the so-called mel spectrogram which is something like a regular spectrogram, but the power and frequency are represented in log scale, which more naturally aligns with human perceptual processing.  You can run the code below to display the mel spectrogram from the audio sample.
#
# You can easily see the four notes played in the audio track.  You also see the 'harmonics' of each notes, which are other tones at integer multiples of the fundamental frequency of each note.

# %%
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
librosa.display.specshow(librosa.amplitude_to_db(S),
                         y_axis='mel', fmax=8000, x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel spectrogram')
plt.tight_layout()

# %% [markdown]
# ## Downloading the Data
#
# Using the MFCC features described above, Eric Humphrey and Juan Bellow have created a complete data set that can used for instrument classification.  Essentially, they collected a number of data files from the website above.  For each audio file, the segmented the track into notes and then extracted 120 MFCCs for each note.  The goal is to recognize the instrument from the 120 MFCCs.  The process of feature extraction is quite involved.  So, we will just use their processed data provided at:
#
# https://github.com/marl/dl4mir-tutorial/blob/master/README.md
#
# Note the password.  Load the four files into some directory, say  `instrument_dataset`.  Then, load them with the commands.

# %%
data_dir = 'instrument_dataset/'
Xtr = np.load(data_dir+'uiowa_train_data.npy')
ytr = np.load(data_dir+'uiowa_train_labels.npy')
Xts = np.load(data_dir+'uiowa_test_data.npy')
yts = np.load(data_dir+'uiowa_test_labels.npy')

# %% [markdown]
# Looking at the data files:
# * What are the number of training and test samples?
# * What is the number of features for each sample?
# * How many classes (i.e. instruments) are there per class?

# %%
# TODO 3
print('Training size: {}, Testing Size: {}'.format(Xtr.shape[0], Xts.shape[0]))
print('Number of feateures = {}'.format(Xtr.shape[1]))
print('Number of classes = {}'.format(len(set(ytr))))

for i in range(10):
    print('Samples in class {} = {}'.format(i, np.sum(ytr == i) + np.sum(yts ==i)))
# Out:
# Training size: 66247, Testing Size: 14904
# Number of feateures = 120
# Number of classes = 10
# Samples in class 0 = 8206
# Samples in class 1 = 2608
# Samples in class 2 = 5038
# Samples in class 3 = 10763
# Samples in class 4 = 5117
# Samples in class 5 = 11354
# Samples in class 6 = 14699
# Samples in class 7 = 3143
# Samples in class 8 = 2613
# Samples in class 9 = 17610

# %% [markdown]
# Before continuing, you must scale the training and test data, `Xtr` and `Xts`.  Compute the mean and std deviation of each feature in `Xtr` and create a new training data set, `Xtr_scale`, by subtracting the mean and dividing by the std deviation.  Also compute a scaled test data set, `Xts_scale` using the mean and std deviation learned from the training data set.

# %%
# TODO 4: Scale the training and test matrices
Xtr_mean = np.mean(Xtr, axis= 0)
Xtr_std = np.std(Xtr, axis= 0)

Xtr_scale = (Xtr - Xtr_mean) / Xtr_std
Xts_scale = (Xts - Xtr_mean) / Xtr_std

# %% [markdown]
# ## Building a Neural Network Classifier
#
# Following the example in [MNIST neural network demo](./mnist_neural.ipynb), clear the keras session.  Then, create a neural network `model` with:
# * `nh=256` hidden units
# * `sigmoid` activation
# * select the input and output shapes correctly
# * print the model summary

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Activation
import tensorflow.keras.backend as K

# %%
# TODO 5 clear session
K.clear_session()

# %%
# TODO 6: construct the model
nin = Xtr_scale.shape[1]
nh = 256
nout = len(set(ytr))

model = Sequential()
model.add(Dense(units=nh, input_shape=(nin,), activation='sigmoid', name='hidden'))
model.add(Dense(units=nout, activation='softmax', name='output'))

# %%
# TODO 7:  Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden (Dense)               (None, 256)               30976
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 33,546
# Trainable params: 33,546
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Create an optimizer and compile the model.  Select the appropriate loss function and metrics.  For the optimizer, use the Adam optimizer with a learning rate of 0.001

# %%
# TODO 8
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2db6bec4a930> in <module>()
#       1 # TODO 8
# ----> 2 model.compile(optimizer='Adam',
#       3               loss='sparse_categorical_crossentropy',
#       4               metrics=['accuracy'])
#
# NameError: name 'model' is not defined

# %% [markdown]
# Fit the model for 10 epochs using the scaled data for both the training and validation.  Use the `validation_data` option to pass the test data.  Also, pass the callback class create above.  Use a batch size of 100.  Your final accuracy should be >99%.

# %%
# TODO 9
hist = model.fit(Xtr_scale, ytr, epochs=10, batch_size=100, validation_data=(Xts_scale ,yts))
# Out:
# Epoch 1/10
# 663/663 [==============================] - 1s 981us/step - loss: 0.3699 - accuracy: 0.8986 - val_loss: 0.2006 - val_accuracy: 0.9424
# Epoch 2/10
# 663/663 [==============================] - 1s 813us/step - loss: 0.1048 - accuracy: 0.9745 - val_loss: 0.1086 - val_accuracy: 0.9676
# Epoch 3/10
# 663/663 [==============================] - 1s 937us/step - loss: 0.0614 - accuracy: 0.9854 - val_loss: 0.0718 - val_accuracy: 0.9781
# Epoch 4/10
# 663/663 [==============================] - 1s 855us/step - loss: 0.0432 - accuracy: 0.9891 - val_loss: 0.0502 - val_accuracy: 0.9878
# Epoch 5/10
# 663/663 [==============================] - 1s 828us/step - loss: 0.0328 - accuracy: 0.9918 - val_loss: 0.0448 - val_accuracy: 0.9871
# Epoch 6/10
# 663/663 [==============================] - 1s 815us/step - loss: 0.0257 - accuracy: 0.9935 - val_loss: 0.0321 - val_accuracy: 0.9913
# Epoch 7/10
# 663/663 [==============================] - 1s 806us/step - loss: 0.0212 - accuracy: 0.9945 - val_loss: 0.0329 - val_accuracy: 0.9902
# Epoch 8/10
# 663/663 [==============================] - 1s 815us/step - loss: 0.0179 - accuracy: 0.9952 - val_loss: 0.0274 - val_accuracy: 0.9915
# Epoch 9/10
# 663/663 [==============================] - 1s 791us/step - loss: 0.0153 - accuracy: 0.9961 - val_loss: 0.0276 - val_accuracy: 0.9909
# Epoch 10/10
# 663/663 [==============================] - 1s 805us/step - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.0251 - val_accuracy: 0.9920

# %% [markdown]
# Plot the validation accuracy saved in `hist.history` dictionary. This gives one accuracy value per epoch.  You should see that the validation accuracy saturates at a little higher than 99%.  After that it "bounces around" due to the noise in the stochastic gradient descent.

# %%
# TODO 10
tr_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

plt.plot(tr_accuracy)
plt.plot(val_accuracy)
plt.grid()
plt.xlabel('epochs')
plt.ylabel('accuarcy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Plot the loss values saved in the `hist.history` dictionary.  You should see that the loss is steadily decreasing.  Use the `semilogy` plot.

# %%
# TODO 11
plt.semilogy(hist.history['loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ## Optimizing the Learning Rate
#
# One challenge in training neural networks is the selection of the learning rate.  Rerun the above code, trying four learning rates as shown in the vector `rates`.  For each learning rate:
# * clear the session
# * construct the network
# * select the optimizer.  Use the Adam optimizer with the appropriate learrning rate.
# * train the model for 20 epochs
# * save the accuracy and losses

# %%
rates = [0.01,0.001,0.0001]
batch_size = 100
loss_hist = []

# TODO 12
for lr in rates:
    K.clear_session()
    
    model = Sequential()
    model.add(Dense(units=nh, input_shape=(nin,), activation='sigmoid', name='hidden'))
    model.add(Dense(units=nout, activation='softmax', name='output'))
    
    opt = optimizers.Adam(lr=lr)
    model.compile(optimizer=opt,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    hist = model.fit(Xtr_scale, ytr, epochs=20, batch_size=batch_size, validation_data=(Xts_scale ,yts))
    loss_hist.append(hist.history['loss'])
# Out:
# Epoch 1/20
# 663/663 [==============================] - 1s 1ms/step - loss: 0.1089 - accuracy: 0.9670 - val_loss: 0.0767 - val_accuracy: 0.9713
# Epoch 2/20
# 663/663 [==============================] - 1s 825us/step - loss: 0.0307 - accuracy: 0.9894 - val_loss: 0.0516 - val_accuracy: 0.9796
# Epoch 3/20
# 663/663 [==============================] - 1s 818us/step - loss: 0.0201 - accuracy: 0.9933 - val_loss: 0.0280 - val_accuracy: 0.9900
# Epoch 4/20
# 663/663 [==============================] - 1s 898us/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 0.0463 - val_accuracy: 0.9836
# Epoch 5/20
# 663/663 [==============================] - 1s 846us/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.1558 - val_accuracy: 0.9608
# Epoch 6/20
# 663/663 [==============================] - 1s 818us/step - loss: 0.0140 - accuracy: 0.9959 - val_loss: 0.0575 - val_accuracy: 0.9834
# Epoch 7/20
# 663/663 [==============================] - 1s 839us/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0558 - val_accuracy: 0.9841
# Epoch 8/20
# 663/663 [==============================] - 1s 832us/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.0366 - val_accuracy: 0.9879
# Epoch 9/20
# 663/663 [==============================] - 1s 845us/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.0815 - val_accuracy: 0.9780
# Epoch 10/20
# 663/663 [==============================] - 1s 838us/step - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.0375 - val_accuracy: 0.9905
# Epoch 11/20
# 663/663 [==============================] - 1s 843us/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.0491 - val_accuracy: 0.9856
# Epoch 12/20
# 663/663 [==============================] - 1s 845us/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.0559 - val_accuracy: 0.9855
# Epoch 13/20
# 663/663 [==============================] - 1s 876us/step - loss: 0.0118 - accuracy: 0.9967 - val_loss: 0.0451 - val_accuracy: 0.9868
# Epoch 14/20
# 663/663 [==============================] - 1s 909us/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0850 - val_accuracy: 0.9810
# Epoch 15/20
# 663/663 [==============================] - 1s 867us/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0758 - val_accuracy: 0.9807
# Epoch 16/20
# 663/663 [==============================] - 1s 875us/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.1149 - val_accuracy: 0.9764
# Epoch 17/20
# 663/663 [==============================] - 1s 850us/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.1316 - val_accuracy: 0.9750
# Epoch 18/20
# 663/663 [==============================] - 1s 851us/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0581 - val_accuracy: 0.9879
# Epoch 19/20
# 663/663 [==============================] - 1s 841us/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.1250 - val_accuracy: 0.9803
# Epoch 20/20
# 663/663 [==============================] - 1s 888us/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.1192 - val_accuracy: 0.9756
# Epoch 1/20
# 663/663 [==============================] - 1s 967us/step - loss: 0.3687 - accuracy: 0.8989 - val_loss: 0.1968 - val_accuracy: 0.9432
# Epoch 2/20
# 663/663 [==============================] - 1s 829us/step - loss: 0.1056 - accuracy: 0.9740 - val_loss: 0.0911 - val_accuracy: 0.9764
# Epoch 3/20
# 663/663 [==============================] - 1s 829us/step - loss: 0.0616 - accuracy: 0.9851 - val_loss: 0.0587 - val_accuracy: 0.9870
# Epoch 4/20
# 663/663 [==============================] - 1s 895us/step - loss: 0.0425 - accuracy: 0.9891 - val_loss: 0.0550 - val_accuracy: 0.9842
# Epoch 5/20
# 663/663 [==============================] - 1s 879us/step - loss: 0.0319 - accuracy: 0.9922 - val_loss: 0.0381 - val_accuracy: 0.9901
# Epoch 6/20
# 663/663 [==============================] - 1s 824us/step - loss: 0.0253 - accuracy: 0.9933 - val_loss: 0.0354 - val_accuracy: 0.9891
# Epoch 7/20
# 663/663 [==============================] - 1s 823us/step - loss: 0.0207 - accuracy: 0.9946 - val_loss: 0.0303 - val_accuracy: 0.9911
# Epoch 8/20
# 663/663 [==============================] - 1s 819us/step - loss: 0.0172 - accuracy: 0.9955 - val_loss: 0.0303 - val_accuracy: 0.9914
# Epoch 9/20
# 663/663 [==============================] - 1s 827us/step - loss: 0.0148 - accuracy: 0.9964 - val_loss: 0.0235 - val_accuracy: 0.9929
# Epoch 10/20
# 663/663 [==============================] - 1s 820us/step - loss: 0.0129 - accuracy: 0.9965 - val_loss: 0.0221 - val_accuracy: 0.9930
# Epoch 11/20
# 663/663 [==============================] - 1s 825us/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.0226 - val_accuracy: 0.9922
# Epoch 12/20
# 663/663 [==============================] - 1s 829us/step - loss: 0.0100 - accuracy: 0.9975 - val_loss: 0.0235 - val_accuracy: 0.9915
# Epoch 13/20
# 663/663 [==============================] - 1s 824us/step - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.0225 - val_accuracy: 0.9913
# Epoch 14/20
# 663/663 [==============================] - 1s 829us/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0203 - val_accuracy: 0.9928
# Epoch 15/20
# 663/663 [==============================] - 1s 827us/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 0.0234 - val_accuracy: 0.9915
# Epoch 16/20
# 663/663 [==============================] - 1s 838us/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0253 - val_accuracy: 0.9911
# Epoch 17/20
# 663/663 [==============================] - 1s 825us/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0212 - val_accuracy: 0.9926
# Epoch 18/20
# 663/663 [==============================] - 1s 818us/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0283 - val_accuracy: 0.9906
# Epoch 19/20
# 663/663 [==============================] - 1s 823us/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0252 - val_accuracy: 0.9919
# Epoch 20/20
# 663/663 [==============================] - 1s 883us/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.0280 - val_accuracy: 0.9915
# Epoch 1/20
# 663/663 [==============================] - 1s 988us/step - loss: 1.1352 - accuracy: 0.6386 - val_loss: 0.8620 - val_accuracy: 0.6742
# Epoch 2/20
# 663/663 [==============================] - 1s 823us/step - loss: 0.5543 - accuracy: 0.8499 - val_loss: 0.5767 - val_accuracy: 0.8105
# Epoch 3/20
# 663/663 [==============================] - 1s 817us/step - loss: 0.3834 - accuracy: 0.9099 - val_loss: 0.4415 - val_accuracy: 0.8722
# Epoch 4/20
# 663/663 [==============================] - 1s 816us/step - loss: 0.2957 - accuracy: 0.9330 - val_loss: 0.3508 - val_accuracy: 0.9036
# Epoch 5/20
# 663/663 [==============================] - 1s 821us/step - loss: 0.2401 - accuracy: 0.9461 - val_loss: 0.2857 - val_accuracy: 0.9247
# Epoch 6/20
# 663/663 [==============================] - 1s 811us/step - loss: 0.2006 - accuracy: 0.9549 - val_loss: 0.2525 - val_accuracy: 0.9268
# Epoch 7/20
# 663/663 [==============================] - 1s 828us/step - loss: 0.1708 - accuracy: 0.9608 - val_loss: 0.2046 - val_accuracy: 0.9454
# Epoch 8/20
# 663/663 [==============================] - 1s 857us/step - loss: 0.1470 - accuracy: 0.9652 - val_loss: 0.1732 - val_accuracy: 0.9550
# Epoch 9/20
# 663/663 [==============================] - 1s 858us/step - loss: 0.1280 - accuracy: 0.9698 - val_loss: 0.1583 - val_accuracy: 0.9550
# Epoch 10/20
# 663/663 [==============================] - 1s 836us/step - loss: 0.1125 - accuracy: 0.9731 - val_loss: 0.1386 - val_accuracy: 0.9613
# Epoch 11/20
# 663/663 [==============================] - 1s 821us/step - loss: 0.0999 - accuracy: 0.9764 - val_loss: 0.1206 - val_accuracy: 0.9686
# Epoch 12/20
# 663/663 [==============================] - 1s 834us/step - loss: 0.0897 - accuracy: 0.9791 - val_loss: 0.1083 - val_accuracy: 0.9732
# Epoch 13/20
# 663/663 [==============================] - 1s 812us/step - loss: 0.0810 - accuracy: 0.9810 - val_loss: 0.0962 - val_accuracy: 0.9781
# Epoch 14/20
# 663/663 [==============================] - 1s 851us/step - loss: 0.0739 - accuracy: 0.9827 - val_loss: 0.0889 - val_accuracy: 0.9780
# Epoch 15/20
# 663/663 [==============================] - 1s 829us/step - loss: 0.0678 - accuracy: 0.9840 - val_loss: 0.0833 - val_accuracy: 0.9800
# Epoch 16/20
# 663/663 [==============================] - 1s 827us/step - loss: 0.0626 - accuracy: 0.9851 - val_loss: 0.0761 - val_accuracy: 0.9813
# Epoch 17/20
# 663/663 [==============================] - 1s 816us/step - loss: 0.0581 - accuracy: 0.9860 - val_loss: 0.0737 - val_accuracy: 0.9818
# Epoch 18/20
# 663/663 [==============================] - 1s 820us/step - loss: 0.0542 - accuracy: 0.9867 - val_loss: 0.0682 - val_accuracy: 0.9848
# Epoch 19/20
# 663/663 [==============================] - 1s 824us/step - loss: 0.0508 - accuracy: 0.9878 - val_loss: 0.0638 - val_accuracy: 0.9853
# Epoch 20/20
# 663/663 [==============================] - 1s 806us/step - loss: 0.0478 - accuracy: 0.9883 - val_loss: 0.0573 - val_accuracy: 0.9864

# %% [markdown]
# Plot the loss funciton vs. the epoch number for all three learning rates on one graph.  You should see that the lower learning rates are more stable, but converge slower.

# %%
# TODO 13
for i, loss in enumerate(loss_hist):
    plt.semilogy(loss, label='loss lr={}'.format(rates[i]))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
